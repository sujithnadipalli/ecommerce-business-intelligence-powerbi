# %%
print("Welcome")
# Out:
# Welcome

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sqlalchemy import create_engine
print("Libraries Import Sucessfullyy...")
# Out:
# Libraries Import Sucessfullyy...

# %%
from sqlalchemy import create_engine

username = "root"
password = "1779"
host = "localhost"
database = "olist_ecommerce_db"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}/{database}"
)

print("Database Connected Successfully")
# Out:
# Database Connected Successfully

# %%
customers = pd.read_sql("SELECT * FROM customers", engine)

orders = pd.read_sql("SELECT * FROM orders", engine)

payments = pd.read_sql("SELECT * FROM payments", engine)

products = pd.read_sql("SELECT * FROM products", engine)

order_items = pd.read_sql("SELECT * FROM order_items", engine)

reviews = pd.read_sql("SELECT * FROM order_reviews", engine)

sellers = pd.read_sql("SELECT * FROM sellers", engine)

# %%
customers.shape
# Out:
# (99441, 5)

# %%
payments.shape
# Out:
# (103886, 5)

# %%
orders.shape
# Out:
# (99441, 8)

# %%
products.shape
# Out:
# (32951, 9)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 11.0 MB

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 21.9 MB

# %%
payments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  str
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  str
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 8.1 MB

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  str
#  1   product_category_name       32341 non-null  str
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), str(2)
# memory usage: 3.7 MB

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
payments.isnull().sum()
products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
master_df = orders.merge(customers, on='customer_id', how='left') \
                  .merge(payments, on='order_id', how='left') \
                  .merge(order_items, on='order_id', how='left') \
                  .merge(products, on='product_id', how='left') \
                  .merge(reviews, on='order_id', how='left')

# %%
master_df.shape
master_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 2           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 3           2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 4           2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix  ... product_weight_g product_length_cm  \
# 0                      3149  ...            500.0              19.0
# 1                      3149  ...            500.0              19.0
# 2                      3149  ...            500.0              19.0
# 3                     47813  ...            400.0              19.0
# 4                     75265  ...            420.0              24.0
#
#    product_height_cm product_width_cm                         review_id  \
# 0                8.0             13.0  a54f0611adc9ed256b57ede6b6eb5114
# 1                8.0             13.0  a54f0611adc9ed256b57ede6b6eb5114
# 2                8.0             13.0  a54f0611adc9ed256b57ede6b6eb5114
# 3               13.0             19.0  8d5266042046a06655c8db133d120ba5
# 4               19.0             21.0  e73b67b67587f7644d5bd1a52deb1b01
#
#    review_score  review_comment_title  \
# 0           4.0                   NaN
# 1           4.0                   NaN
# 2           4.0                   NaN
# 3           4.0      Muito boa a loja
# 4           5.0                   NaN
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 1  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 2  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 3                               Muito bom o produto.  2018-08-08 00:00:00
# 4                                                NaN  2018-08-18 00:00:00
#
#   review_answer_timestamp
# 0     2017-10-12 03:43:48
# 1     2017-10-12 03:43:48
# 2     2017-10-12 03:43:48
# 3     2018-08-08 18:37:50
# 4     2018-08-22 19:07:58
#
# [5 rows x 36 columns]

# %%
plt.figure(figsize=(8,5))
plt.hist(master_df['payment_value'], bins=50)
plt.title("Revenue Distribution")
plt.xlabel("Payment Value")
plt.ylabel("Frequency")
plt.show()

# %%
top_categories = master_df.groupby('product_category_name')['payment_value'].sum() \
                          .sort_values(ascending=False).head(10)

top_categories.plot(kind='bar', figsize=(10,5))

plt.title("Top 10 Categories by Revenue")
plt.ylabel("Revenue")
plt.show()

# %%
master_df['review_score'].value_counts().sort_index().plot(
    kind='bar',
    figsize=(7,5)
)

plt.title("Review Score Distribution")
plt.xlabel("Review Score")
plt.ylabel("Count")
plt.show()

# %%
payments['payment_type'].value_counts().plot(
    kind='bar',
    figsize=(7,5)
)

plt.title("Payment Types")
plt.show()

# %%
orders['order_purchase_timestamp'] = pd.to_datetime(
    orders['order_purchase_timestamp']
)

# %%
monthly_orders = orders.groupby(
    orders['order_purchase_timestamp'].dt.to_period('M')
).size()

monthly_orders.plot(figsize=(12,5))

plt.title("Monthly Orders")
plt.show()

# %%
customers['customer_state'].value_counts().head(10).plot(
    kind='bar',
    figsize=(8,5)
)

plt.title("Top 10 States")
plt.show()

# %%
numeric_df = master_df.select_dtypes(include='number')

numeric_df.corr()
# Out:
#                             customer_zip_code_prefix  payment_sequential  \
# customer_zip_code_prefix                    1.000000           -0.021974
# payment_sequential                         -0.021974            1.000000
# payment_installments                        0.056266           -0.086508
# payment_value                               0.054519           -0.064467
# order_item_id                              -0.000528           -0.002871
# price                                       0.043158            0.006839
# freight_value                               0.225510            0.022345
# product_name_lenght                         0.015804           -0.005581
# product_description_lenght                  0.025415            0.009937
# product_photos_qty                          0.020505           -0.010828
# product_weight_g                            0.001620            0.043985
# product_length_cm                           0.004334            0.048959
# product_height_cm                           0.011669            0.024479
# product_width_cm                           -0.011325            0.031062
# review_score                               -0.021886           -0.005766
#
#                             payment_installments  payment_value  \
# customer_zip_code_prefix                0.056266       0.054519
# payment_sequential                     -0.086508      -0.064467
# payment_installments                    1.000000       0.273647
# payment_value                           0.273647       1.000000
# order_item_id                           0.073835       0.265217
# price                                   0.277642       0.739236
# freight_value                           0.185674       0.373762
# product_name_lenght                     0.020843       0.002371
# product_description_lenght              0.036004       0.156108
# product_photos_qty                      0.000118       0.010075
# product_weight_g                        0.177491       0.303326
# product_length_cm                       0.117630       0.138755
# product_height_cm                       0.122231       0.217155
# product_width_cm                        0.137857       0.148606
# review_score                           -0.040446      -0.082343
#
#                             order_item_id     price  freight_value  \
# customer_zip_code_prefix        -0.000528  0.043158       0.225510
# payment_sequential              -0.002871  0.006839       0.022345
# payment_installments             0.073835  0.277642       0.185674
# payment_value                    0.265217  0.739236       0.373762
# order_item_id                    1.000000 -0.060459      -0.030694
# price                           -0.060459  1.000000       0.415938
# freight_value                   -0.030694  0.415938       1.000000
# product_name_lenght             -0.024155  0.018026       0.022628
# product_description_lenght      -0.015059  0.201759       0.096506
# product_photos_qty              -0.054455  0.052818       0.022329
# product_weight_g                -0.004326  0.339367       0.611587
# product_length_cm                0.005348  0.145587       0.309672
# product_height_cm                0.029172  0.224309       0.393865
# product_width_cm                -0.009461  0.172629       0.325325
# review_score                    -0.129398 -0.004492      -0.037013
#
#                             product_name_lenght  product_description_lenght  \
# customer_zip_code_prefix               0.015804                    0.025415
# payment_sequential                    -0.005581                    0.009937
# payment_installments                   0.020843                    0.036004
# payment_value                          0.002371                    0.156108
# order_item_id                         -0.024155                   -0.015059
# price                                  0.018026                    0.201759
# freight_value                          0.022628                    0.096506
# product_name_lenght                    1.000000                    0.090238
# product_description_lenght             0.090238                    1.000000
# product_photos_qty                     0.145439                    0.117888
# product_weight_g                       0.020736                    0.063577
# product_length_cm                      0.058652                    0.007468
# product_height_cm                     -0.030891                    0.074121
# product_width_cm                       0.062133                   -0.068269
# review_score                          -0.006239                    0.010332
#
#                             product_photos_qty  product_weight_g  \
# customer_zip_code_prefix              0.020505          0.001620
# payment_sequential                   -0.010828          0.043985
# payment_installments                  0.000118          0.177491
# payment_value                         0.010075          0.303326
# order_item_id                        -0.054455         -0.004326
# price                                 0.052818          0.339367
# freight_value                         0.022329          0.611587
# product_name_lenght                   0.145439          0.020736
# product_description_lenght            0.117888          0.063577
# product_photos_qty                    1.000000          0.021535
# product_weight_g                      0.021535          1.000000
# product_length_cm                     0.044662          0.463108
# product_height_cm                    -0.033464          0.581970
# product_width_cm                      0.006953          0.506897
# review_score                          0.022304         -0.028622
#
#                             product_length_cm  product_height_cm  \
# customer_zip_code_prefix             0.004334           0.011669
# payment_sequential                   0.048959           0.024479
# payment_installments                 0.117630           0.122231
# payment_value                        0.138755           0.217155
# order_item_id                        0.005348           0.029172
# price                                0.145587           0.224309
# freight_value                        0.309672           0.393865
# product_name_lenght                  0.058652          -0.030891
# product_description_lenght           0.007468           0.074121
# product_photos_qty                   0.044662          -0.033464
# product_weight_g                     0.463108           0.581970
# product_length_cm                    1.000000           0.193398
# product_height_cm                    0.193398           1.000000
# product_width_cm                     0.535370           0.279850
# review_score                        -0.020390          -0.026405
#
#                             product_width_cm  review_score
# customer_zip_code_prefix           -0.011325     -0.021886
# payment_sequential                  0.031062     -0.005766
# payment_installments                0.137857     -0.040446
# payment_value                       0.148606     -0.082343
# order_item_id                      -0.009461     -0.129398
# price                               0.172629     -0.004492
# freight_value                       0.325325     -0.037013
# product_name_lenght                 0.062133     -0.006239
# product_description_lenght         -0.068269      0.010332
# product_photos_qty                  0.006953      0.022304
# product_weight_g                    0.506897     -0.028622
# product_length_cm                   0.535370     -0.020390
# product_height_cm                   0.279850     -0.026405
# product_width_cm                    1.000000     -0.010709
# review_score                       -0.010709      1.000000
