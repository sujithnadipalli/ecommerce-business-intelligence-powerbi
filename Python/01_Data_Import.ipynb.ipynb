# %%
print("Hello Sujith")
# Out:
# Hello Sujith

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

print("All libraries are installed successfully!")
# Out:
# All libraries are installed successfully!

# %%
from sqlalchemy import create_engine

username = "root"
password = "1779"   
host = "localhost"
database = "olist_ecommerce_db"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}/{database}"
)

# Test the connection
with engine.connect() as conn:
    print("✅ Database Connected Successfully!")
# Out:
# ✅ Database Connected Successfully!

# %%
import pandas as pd

# Read the customers CSV
customers = pd.read_csv(
    r"C:\Users\sujit\OneDrive\Pictures\Documents\Enterprise-Ecommerce-Analytics\dataset\olist_customers_dataset.csv"
)

# Display first 5 rows
print(customers.head())

# Import into MySQL
customers.to_sql(
    name="customers",
    con=engine,
    if_exists="replace",
    index=False
)

print("✅ Customers table imported successfully!")
print("Total Rows:", len(customers))
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# ✅ Customers table imported successfully!
# Total Rows: 99441

# %%
import pandas as pd

# Folder containing all CSV files
folder = r"C:\Users\sujit\OneDrive\Pictures\Documents\Enterprise-Ecommerce-Analytics\dataset"

# CSV file name : MySQL table name
files = {
    "olist_customers_dataset.csv": "customers",
    "olist_orders_dataset.csv": "orders",
    "olist_order_items_dataset.csv": "order_items",
    "olist_order_payments_dataset.csv": "order_payments",
    "olist_order_reviews_dataset.csv": "order_reviews",
    "olist_products_dataset.csv": "products",
    "olist_sellers_dataset.csv": "sellers",
    "olist_geolocation_dataset.csv": "geolocation",
    "product_category_name_translation.csv": "category_translation"
}

for file, table in files.items():
    print(f"Importing {table}...")

    df = pd.read_csv(f"{folder}\\{file}")

    df.to_sql(
        name=table,
        con=engine,
        if_exists="replace",
        index=False
    )

    print(f"✅ {table} imported ({len(df)} rows)")

print("\n🎉 All tables imported successfully!")
# Out:
# Importing customers...
# ✅ customers imported (99441 rows)
# Importing orders...
# ✅ orders imported (99441 rows)
# Importing order_items...
# ✅ order_items imported (112650 rows)
# Importing order_payments...
# ✅ order_payments imported (103886 rows)
# Importing order_reviews...
# ✅ order_reviews imported (99224 rows)
# Importing products...
# ✅ products imported (32951 rows)
# Importing sellers...
# ✅ sellers imported (3095 rows)
# Importing geolocation...
# ✅ geolocation imported (1000163 rows)
# Importing category_translation...
# ✅ category_translation imported (71 rows)
#
# 🎉 All tables imported successfully!
